# %%
# Cellule 1 — Imports de base et configuration

import numpy as np
import torch
import gymnasium as gym
from gymnasium import spaces

from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker

from stable_baselines3.common.callbacks import EvalCallback

from env.workshop_env import WorkshopEnv  # ton environnement atelier

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
# Cellule 2 — Environnement d'entraînement avec masque d'actions

def mask_fn(env: WorkshopEnv):
    """
    Fonction utilisée par ActionMasker pour récupérer le masque des actions.
    """
    return env.get_action_mask()

# Environnement enveloppé pour PPO
env_train = ActionMasker(WorkshopEnv(), mask_fn)

print("Espace d'observation :", env_train.observation_space)
print("Espace d'actions     :", env_train.action_space)
# Out:
# Espace d'observation : Box(0.0, [1.008e+04 1.000e+00 1.000e+02 1.000e+00 1.000e+02 5.000e+01 5.000e+01
#  5.000e+01 5.000e+01 1.008e+04 1.000e+03 1.000e+03 1.000e+03 4.000e+00
#  5.000e+01 2.000e+02 1.439e+03 2.000e+03 2.000e+04 1.000e+00 1.000e+06
#  1.000e+05 1.500e+01], (23,), float32)
# Espace d'actions     : Discrete(201)

# %%
# ======================================================
# Cellule 3 — Chargement modèle DAgger + réglages PPO SAFE
# ======================================================

from stable_baselines3.common.utils import get_schedule_fn

MODEL_PATH = "student_dagger_expertv4_final.zip"

# Chargement du modèle issu de DAgger
model_ppo = MaskablePPO.load(
    MODEL_PATH,
    env=env_train,
    device="cuda"
)

print("Modèle initial chargé depuis", MODEL_PATH)

# ======================================================
# Hyperparamètres SAFE pour un finetuning PPO NON destructif
# (on NE TOUCHE PAS à n_steps ni batch_size, pour ne pas casser le buffer)
# ======================================================

# 1) Learning rate très faible : micro-ajustements uniquement
NEW_LR = 1e-5
for param_group in model_ppo.policy.optimizer.param_groups:
    param_group["lr"] = NEW_LR
model_ppo.learning_rate = NEW_LR  # pour cohérence interne

# 2) clip_range doit être une FONCTION (schedule), pas un float
#    Ici on impose un clip constant à 0.05
model_ppo.clip_range = get_schedule_fn(0.05)

# 3) Réduire un peu l’exploration intrinsèque
model_ppo.ent_coef = 0.001

# On laisse n_steps et batch_size tels qu'ils ont été sauvés dans le modèle
print("\n=== Hyperparamètres PPO SAFE configurés ===")
print("learning_rate      =", NEW_LR)
print("clip_range         = constant schedule à 0.05")
print("ent_coef           =", model_ppo.ent_coef)
print("n_steps (conservé) =", model_ppo.n_steps)
print("batch_size (conservé) =", model_ppo.batch_size)
print("================================================\n")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Modèle initial chargé depuis student_dagger_final.zip
#
# === Hyperparamètres PPO SAFE configurés ===
# learning_rate      = 1e-05
# clip_range         = constant schedule à 0.05
# ent_coef           = 0.001
# n_steps (conservé) = 4096
# batch_size (conservé) = 512
# ================================================
# C:\Users\fabri\anaconda3\envs\qlearning\lib\site-packages\stable_baselines3\common\utils.py:168: UserWarning: get_schedule_fn() is deprecated, please use FloatSchedule() instead
#   warnings.warn("get_schedule_fn() is deprecated, please use FloatSchedule() instead")
# C:\Users\fabri\anaconda3\envs\qlearning\lib\site-packages\stable_baselines3\common\utils.py:214: UserWarning: constant_fn() is deprecated, please use ConstantSchedule() instead
#   warnings.warn("constant_fn() is deprecated, please use ConstantSchedule() instead")

# %%
# Cellule 4 — Fonction d'évaluation sur N semaines complètes

def evaluate_model_weekly(model, n_episodes: int = 5, max_steps: int = 10080):
    """
    Évalue le modèle sur n_episodes semaines complètes.
    Retourne la liste des rewards.
    """
    rewards = []

    for ep in range(n_episodes):
        env_eval = WorkshopEnv()
        obs, info = env_eval.reset()
        total_reward = 0.0

        for t in range(max_steps):
            mask = env_eval.get_action_mask()
            action, _ = model.predict(
                obs,
                deterministic=True,
                action_masks=mask
            )
            obs, r, terminated, truncated, info = env_eval.step(action)
            total_reward += r

            if terminated or truncated:
                break

        rewards.append(total_reward)
        print(f"Episode {ep+1}/{n_episodes} — reward = {total_reward:.2f}")

    rewards = np.array(rewards, dtype=np.float32)
    print(f"\nReward moyen sur {n_episodes} semaines : {rewards.mean():.2f} ± {rewards.std():.2f}")
    return rewards

# %%
# Cellule 5 — Baseline : évaluation AVANT finetuning PPO

print("=== Évaluation AVANT PPO (policy issue de DAgger) ===")
rewards_before = evaluate_model_weekly(model_ppo, n_episodes=5)
# Out:
# === Évaluation AVANT PPO (policy issue de DAgger) ===
# Episode 1/5 — reward = 11012.98
# Episode 2/5 — reward = 10339.32
# Episode 3/5 — reward = 11129.16
# Episode 4/5 — reward = 10696.86
# Episode 5/5 — reward = 9855.36
#
# Reward moyen sur 5 semaines : 10606.74 ± 465.22

# %%
# Cellule 6 — Environnement d'évaluation + callback

eval_env = ActionMasker(WorkshopEnv(), mask_fn)

eval_callback = EvalCallback(
    eval_env,
    n_eval_episodes=3,              # 3 semaines complètes pour une éval
    eval_freq=20_000,               # tous les 20k timesteps
    best_model_save_path="./ppo_safe_best_v4",
    deterministic=True,
    render=False
)

print("Callback d'évaluation initialisé.")
# Out:
# Callback d'évaluation initialisé.

# %%
# Cellule 7 — Entraînement PPO avec contraintes "safe"
from datetime import datetime

TOTAL_TIMESTEPS = 300_000
LOG_NAME = f"ppo_safe_finetune_v4_{datetime.now().strftime('%Y%m%d_%H%M')}"

print(f"=== Entraînement PPO (safe) pour {TOTAL_TIMESTEPS} timesteps ===")

model_ppo.set_env(env_train) # par sécurité

model_ppo.learn( total_timesteps=TOTAL_TIMESTEPS, tb_log_name=LOG_NAME, callback=eval_callback, progress_bar=True )

print("=== Fin de l'entraînement PPO (safe) ===")
# Out:
# === Entraînement PPO (safe) pour 350000 timesteps ===
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tb_dagger_hybrid\ppo_safe_finetune_v3_20251215_1505_1
# C:\Users\fabri\anaconda3\envs\qlearning\lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# -----------------------------
# | time/              |      |
# |    fps             | 171  |
# |    iterations      | 1    |
# |    time_elapsed    | 23   |
# |    total_timesteps | 4096 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 164           |
# |    iterations           | 2             |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00025716456 |
# |    clip_fraction        | 0.0506        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.472        |
# |    explained_variance   | 0.00213       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 349           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0026       |
# |    value_loss           | 813           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.35e+04      |
# | time/                   |               |
# |    fps                  | 161           |
# |    iterations           | 3             |
# |    time_elapsed         | 76            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00043339975 |
# |    clip_fraction        | 0.0672        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.434        |
# |    explained_variance   | 0.00318       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 266           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00247      |
# |    value_loss           | 618           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.35e+04      |
# | time/                   |               |
# |    fps                  | 161           |
# |    iterations           | 4             |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00024340692 |
# |    clip_fraction        | 0.0559        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.465        |
# |    explained_variance   | 0.0146        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 329           |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00271      |
# |    value_loss           | 699           |
# -------------------------------------------
# C:\Users\fabri\anaconda3\envs\qlearning\lib\site-packages\stable_baselines3\common\evaluation.py:70: UserWarning:
# Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode
# lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor``
# wrapper.
#   warnings.warn(
# Eval num_timesteps=20000, episode_reward=-423.92 +/- 351.46
# Episode length: 10080.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+04     |
# |    mean_reward          | -424         |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0002606599 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.409       |
# |    explained_variance   | 0.0023       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 337          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 682          |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.37e+04 |
# | time/              |          |
# |    fps             | 100      |
# |    iterations      | 5        |
# |    time_elapsed    | 204      |
# |    total_timesteps | 20480    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.37e+04     |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 6            |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0003847269 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.461       |
# |    explained_variance   | 0.0154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 315          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 682          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.37e+04      |
# | time/                   |               |
# |    fps                  | 112           |
# |    iterations           | 7             |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00019230435 |
# |    clip_fraction        | 0.0402        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.398        |
# |    explained_variance   | -0.00254      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 366           |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00157      |
# |    value_loss           | 797           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.41e+04     |
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 8            |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0003440266 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.419       |
# |    explained_variance   | 0.000555     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 289          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 631          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.41e+04     |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 9            |
# |    time_elapsed         | 306          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0002496088 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0.00847      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 432          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 852          |
# ------------------------------------------
# Eval num_timesteps=40000, episode_reward=24.96 +/- 219.85
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 25            |
# | time/                   |               |
# |    total_timesteps      | 40000         |
# | train/                  |               |
# |    approx_kl            | 0.00027181098 |
# |    clip_fraction        | 0.0461        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.427        |
# |    explained_variance   | 0.000576      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 294           |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00183      |
# |    value_loss           | 644           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.44e+04 |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 10       |
# |    time_elapsed    | 411      |
# |    total_timesteps | 40960    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.44e+04      |
# | time/                   |               |
# |    fps                  | 103           |
# |    iterations           | 11            |
# |    time_elapsed         | 436           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00022052147 |
# |    clip_fraction        | 0.0388        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.462        |
# |    explained_variance   | 0.00781       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 331           |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.0021       |
# |    value_loss           | 761           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.44e+04      |
# | time/                   |               |
# |    fps                  | 106           |
# |    iterations           | 12            |
# |    time_elapsed         | 461           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00023445091 |
# |    clip_fraction        | 0.056         |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.372        |
# |    explained_variance   | -0.000478     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 328           |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00199      |
# |    value_loss           | 670           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.49e+04     |
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 13           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0002043276 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | -0.000214    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 424          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 829          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.49e+04      |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 14            |
# |    time_elapsed         | 513           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00019626372 |
# |    clip_fraction        | 0.051         |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.416        |
# |    explained_variance   | 0.00705       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 432           |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00222      |
# |    value_loss           | 930           |
# -------------------------------------------
# Eval num_timesteps=60000, episode_reward=545.90 +/- 1084.79
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 546           |
# | time/                   |               |
# |    total_timesteps      | 60000         |
# | train/                  |               |
# |    approx_kl            | 0.00020134143 |
# |    clip_fraction        | 0.0448        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.409        |
# |    explained_variance   | 0.000488      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 343           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 707           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.52e+04 |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 15       |
# |    time_elapsed    | 620      |
# |    total_timesteps | 61440    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.52e+04      |
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 16            |
# |    time_elapsed         | 645           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00017147503 |
# |    clip_fraction        | 0.0453        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.418        |
# |    explained_variance   | 0.00484       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 361           |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.0022       |
# |    value_loss           | 677           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.52e+04     |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 17           |
# |    time_elapsed         | 671          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0001730324 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.347       |
# |    explained_variance   | 4.61e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 339          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 758          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.55e+04      |
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 18            |
# |    time_elapsed         | 696           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00016199339 |
# |    clip_fraction        | 0.0363        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.372        |
# |    explained_variance   | -9.2e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 321           |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00122      |
# |    value_loss           | 745           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.55e+04      |
# | time/                   |               |
# |    fps                  | 107           |
# |    iterations           | 19            |
# |    time_elapsed         | 721           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00018361247 |
# |    clip_fraction        | 0.0456        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.4          |
# |    explained_variance   | 0.00514       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 336           |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00232      |
# |    value_loss           | 732           |
# -------------------------------------------
# Eval num_timesteps=80000, episode_reward=1110.17 +/- 435.71
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 1.11e+03      |
# | time/                   |               |
# |    total_timesteps      | 80000         |
# | train/                  |               |
# |    approx_kl            | 0.00011252258 |
# |    clip_fraction        | 0.0222        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.343        |
# |    explained_variance   | -4.4e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 353           |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00104      |
# |    value_loss           | 751           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.57e+04 |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 20       |
# |    time_elapsed    | 826      |
# |    total_timesteps | 81920    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.57e+04      |
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 21            |
# |    time_elapsed         | 850           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00013507358 |
# |    clip_fraction        | 0.0269        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.393        |
# |    explained_variance   | 0.00466       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 360           |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00166      |
# |    value_loss           | 770           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.57e+04      |
# | time/                   |               |
# |    fps                  | 103           |
# |    iterations           | 22            |
# |    time_elapsed         | 872           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00010653983 |
# |    clip_fraction        | 0.0343        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.392        |
# |    explained_variance   | -5.36e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 332           |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00121      |
# |    value_loss           | 719           |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 1.01e+04       |
# |    ep_rew_mean          | 1.59e+04       |
# | time/                   |                |
# |    fps                  | 105            |
# |    iterations           | 23             |
# |    time_elapsed         | 896            |
# |    total_timesteps      | 94208          |
# | train/                  |                |
# |    approx_kl            | 0.000118357006 |
# |    clip_fraction        | 0.0271         |
# |    clip_range           | 0.05           |
# |    entropy_loss         | -0.333         |
# |    explained_variance   | -5.01e-05      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 301            |
# |    n_updates            | 220            |
# |    policy_gradient_loss | -0.00115       |
# |    value_loss           | 608            |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.59e+04      |
# | time/                   |               |
# |    fps                  | 106           |
# |    iterations           | 24            |
# |    time_elapsed         | 921           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00027616622 |
# |    clip_fraction        | 0.0382        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.41         |
# |    explained_variance   | 0.00526       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 291           |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00214      |
# |    value_loss           | 625           |
# -------------------------------------------
# Eval num_timesteps=100000, episode_reward=686.16 +/- 645.71
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 686           |
# | time/                   |               |
# |    total_timesteps      | 100000        |
# | train/                  |               |
# |    approx_kl            | 0.00020443206 |
# |    clip_fraction        | 0.0346        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.396        |
# |    explained_variance   | -8.7e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 373           |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00136      |
# |    value_loss           | 822           |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.6e+04  |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 25       |
# |    time_elapsed    | 1024     |
# |    total_timesteps | 102400   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.6e+04      |
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 26           |
# |    time_elapsed         | 1050         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0002104754 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.428       |
# |    explained_variance   | 0.00965      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 340          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 731          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.6e+04      |
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 27           |
# |    time_elapsed         | 1075         |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 8.581217e-05 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | -3.92e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 321          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 687          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.62e+04     |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 28           |
# |    time_elapsed         | 1099         |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 9.153484e-05 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.344       |
# |    explained_variance   | -1.91e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 308          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 649          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.62e+04      |
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 29            |
# |    time_elapsed         | 1125          |
# |    total_timesteps      | 118784        |
# | train/                  |               |
# |    approx_kl            | 0.00025481667 |
# |    clip_fraction        | 0.0402        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.374        |
# |    explained_variance   | 0.0113        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 270           |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00224      |
# |    value_loss           | 635           |
# -------------------------------------------
# Eval num_timesteps=120000, episode_reward=1121.17 +/- 516.67
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 1.12e+03      |
# | time/                   |               |
# |    total_timesteps      | 120000        |
# | train/                  |               |
# |    approx_kl            | 0.00012900739 |
# |    clip_fraction        | 0.0303        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.329        |
# |    explained_variance   | -1.79e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 279           |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00135      |
# |    value_loss           | 620           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.63e+04 |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 30       |
# |    time_elapsed    | 1228     |
# |    total_timesteps | 122880   |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.63e+04      |
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 31            |
# |    time_elapsed         | 1254          |
# |    total_timesteps      | 126976        |
# | train/                  |               |
# |    approx_kl            | 0.00021894279 |
# |    clip_fraction        | 0.0451        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.423        |
# |    explained_variance   | 0.018         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 310           |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00231      |
# |    value_loss           | 612           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.63e+04      |
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 32            |
# |    time_elapsed         | 1280          |
# |    total_timesteps      | 131072        |
# | train/                  |               |
# |    approx_kl            | 0.00016358982 |
# |    clip_fraction        | 0.0452        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.388        |
# |    explained_variance   | -0.000127     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 265           |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.00169      |
# |    value_loss           | 539           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.63e+04      |
# | time/                   |               |
# |    fps                  | 103           |
# |    iterations           | 33            |
# |    time_elapsed         | 1306          |
# |    total_timesteps      | 135168        |
# | train/                  |               |
# |    approx_kl            | 0.00021276966 |
# |    clip_fraction        | 0.0294        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.322        |
# |    explained_variance   | 0.0607        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 265           |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.00206      |
# |    value_loss           | 580           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.63e+04     |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 34           |
# |    time_elapsed         | 1332         |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 8.658481e-05 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.376       |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 276          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 572          |
# ------------------------------------------
# Eval num_timesteps=140000, episode_reward=2283.23 +/- 309.08
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 2.28e+03      |
# | time/                   |               |
# |    total_timesteps      | 140000        |
# | train/                  |               |
# |    approx_kl            | 0.00010253819 |
# |    clip_fraction        | 0.0296        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.354        |
# |    explained_variance   | 4.32e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 286           |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00119      |
# |    value_loss           | 620           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.64e+04 |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 35       |
# |    time_elapsed    | 1434     |
# |    total_timesteps | 143360   |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.64e+04      |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 36            |
# |    time_elapsed         | 1460          |
# |    total_timesteps      | 147456        |
# | train/                  |               |
# |    approx_kl            | 0.00017500095 |
# |    clip_fraction        | 0.0364        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.434        |
# |    explained_variance   | 0.289         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 290           |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.00196      |
# |    value_loss           | 612           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.64e+04      |
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 37            |
# |    time_elapsed         | 1485          |
# |    total_timesteps      | 151552        |
# | train/                  |               |
# |    approx_kl            | 0.00015022318 |
# |    clip_fraction        | 0.0405        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.46         |
# |    explained_variance   | 1.02e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 190           |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 437           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.64e+04      |
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 38            |
# |    time_elapsed         | 1511          |
# |    total_timesteps      | 155648        |
# | train/                  |               |
# |    approx_kl            | 0.00024761923 |
# |    clip_fraction        | 0.0415        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.451        |
# |    explained_variance   | 0.358         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 270           |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00217      |
# |    value_loss           | 573           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+04    |
# |    ep_rew_mean          | 1.64e+04    |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 39          |
# |    time_elapsed         | 1536        |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.000126583 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.05        |
# |    entropy_loss         | -0.428      |
# |    explained_variance   | -4.05e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 209         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 511         |
# -----------------------------------------
# Eval num_timesteps=160000, episode_reward=4701.34 +/- 1159.70
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 4.7e+03       |
# | time/                   |               |
# |    total_timesteps      | 160000        |
# | train/                  |               |
# |    approx_kl            | 0.00014268092 |
# |    clip_fraction        | 0.0418        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.39         |
# |    explained_variance   | 1.5e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 204           |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.00142      |
# |    value_loss           | 486           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.64e+04 |
# | time/              |          |
# |    fps             | 100      |
# |    iterations      | 40       |
# |    time_elapsed    | 1637     |
# |    total_timesteps | 163840   |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.64e+04      |
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 41            |
# |    time_elapsed         | 1662          |
# |    total_timesteps      | 167936        |
# | train/                  |               |
# |    approx_kl            | 0.00012236896 |
# |    clip_fraction        | 0.0248        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.408        |
# |    explained_variance   | 0.415         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 290           |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.0018       |
# |    value_loss           | 567           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.65e+04     |
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 42           |
# |    time_elapsed         | 1688         |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 9.694949e-05 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.339       |
# |    explained_variance   | 8.29e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 263          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 491          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.65e+04      |
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 43            |
# |    time_elapsed         | 1714          |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 0.00020209448 |
# |    clip_fraction        | 0.0503        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.502        |
# |    explained_variance   | 0.411         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 208           |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00178      |
# |    value_loss           | 495           |
# -------------------------------------------
# Eval num_timesteps=180000, episode_reward=5950.36 +/- 546.91
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 5.95e+03      |
# | time/                   |               |
# |    total_timesteps      | 180000        |
# | train/                  |               |
# |    approx_kl            | 0.00018448522 |
# |    clip_fraction        | 0.0528        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.445        |
# |    explained_variance   | -7.62e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 195           |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00196      |
# |    value_loss           | 410           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.65e+04 |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 44       |
# |    time_elapsed    | 1818     |
# |    total_timesteps | 180224   |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.65e+04      |
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 45            |
# |    time_elapsed         | 1843          |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.00016384372 |
# |    clip_fraction        | 0.0349        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.403        |
# |    explained_variance   | 5.3e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 201           |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00154      |
# |    value_loss           | 442           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.65e+04     |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 46           |
# |    time_elapsed         | 1868         |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0001935852 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 222          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 476          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.64e+04      |
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 47            |
# |    time_elapsed         | 1893          |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00017559913 |
# |    clip_fraction        | 0.0384        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.502        |
# |    explained_variance   | 6.74e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 170           |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.00154      |
# |    value_loss           | 363           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.64e+04      |
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 48            |
# |    time_elapsed         | 1920          |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00032037118 |
# |    clip_fraction        | 0.0559        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.571        |
# |    explained_variance   | 0.407         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 199           |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.00232      |
# |    value_loss           | 412           |
# -------------------------------------------
# Eval num_timesteps=200000, episode_reward=4995.31 +/- 1159.61
# Episode length: 10080.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+04     |
# |    mean_reward          | 5e+03        |
# | time/                   |              |
# |    total_timesteps      | 200000       |
# | train/                  |              |
# |    approx_kl            | 0.0001834915 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | 1.49e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 385          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.64e+04 |
# | time/              |          |
# |    fps             | 98       |
# |    iterations      | 49       |
# ...
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 164          |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.000859    |
# |    value_loss           | 284          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.6e+04       |
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 71            |
# |    time_elapsed         | 2916          |
# |    total_timesteps      | 290816        |
# | train/                  |               |
# |    approx_kl            | 0.00011128532 |
# |    clip_fraction        | 0.0245        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.404        |
# |    explained_variance   | 3.52e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 154           |
# |    n_updates            | 700           |
# |    policy_gradient_loss | -0.00115      |
# |    value_loss           | 300           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.6e+04      |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 72           |
# |    time_elapsed         | 2942         |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0002681541 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 139          |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 259          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.6e+04       |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 73            |
# |    time_elapsed         | 2969          |
# |    total_timesteps      | 299008        |
# | train/                  |               |
# |    approx_kl            | 0.00031700663 |
# |    clip_fraction        | 0.0471        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.469        |
# |    explained_variance   | 0.265         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 170           |
# |    n_updates            | 720           |
# |    policy_gradient_loss | -0.00247      |
# |    value_loss           | 371           |
# -------------------------------------------
# Eval num_timesteps=300000, episode_reward=-828.09 +/- 96.70
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | -828          |
# | time/                   |               |
# |    total_timesteps      | 300000        |
# | train/                  |               |
# |    approx_kl            | 0.00018760236 |
# |    clip_fraction        | 0.0322        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.479        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 183           |
# |    n_updates            | 730           |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 366           |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.6e+04  |
# | time/              |          |
# |    fps             | 98       |
# |    iterations      | 74       |
# |    time_elapsed    | 3076     |
# |    total_timesteps | 303104   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.6e+04      |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 75           |
# |    time_elapsed         | 3100         |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0021700552 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 235          |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 436          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.6e+04       |
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 76            |
# |    time_elapsed         | 3126          |
# |    total_timesteps      | 311296        |
# | train/                  |               |
# |    approx_kl            | 0.00010060043 |
# |    clip_fraction        | 0.0188        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.423        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 157           |
# |    n_updates            | 750           |
# |    policy_gradient_loss | -0.000926     |
# |    value_loss           | 341           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+04    |
# |    ep_rew_mean          | 1.59e+04    |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 77          |
# |    time_elapsed         | 3152        |
# |    total_timesteps      | 315392      |
# | train/                  |             |
# |    approx_kl            | 0.005804197 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.05        |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 178         |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.00633     |
# |    value_loss           | 345         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.59e+04      |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 78            |
# |    time_elapsed         | 3178          |
# |    total_timesteps      | 319488        |
# | train/                  |               |
# |    approx_kl            | 0.00059258984 |
# |    clip_fraction        | 0.27          |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.351        |
# |    explained_variance   | 0.247         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 212           |
# |    n_updates            | 770           |
# |    policy_gradient_loss | 0.022         |
# |    value_loss           | 487           |
# -------------------------------------------
# Eval num_timesteps=320000, episode_reward=7941.05 +/- 235.68
# Episode length: 10080.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.01e+04      |
# |    mean_reward          | 7.94e+03      |
# | time/                   |               |
# |    total_timesteps      | 320000        |
# | train/                  |               |
# |    approx_kl            | 0.00014731004 |
# |    clip_fraction        | 0.0176        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.457        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 188           |
# |    n_updates            | 780           |
# |    policy_gradient_loss | -0.00122      |
# |    value_loss           | 391           |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.59e+04 |
# | time/              |          |
# |    fps             | 98       |
# |    iterations      | 79       |
# |    time_elapsed    | 3283     |
# |    total_timesteps | 323584   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.59e+04     |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 80           |
# |    time_elapsed         | 3308         |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0003388287 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 278          |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 535          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.59e+04      |
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 81            |
# |    time_elapsed         | 3333          |
# |    total_timesteps      | 331776        |
# | train/                  |               |
# |    approx_kl            | 0.00017604949 |
# |    clip_fraction        | 0.0293        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.421        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 124           |
# |    n_updates            | 800           |
# |    policy_gradient_loss | -0.00151      |
# |    value_loss           | 300           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+04    |
# |    ep_rew_mean          | 1.58e+04    |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 82          |
# |    time_elapsed         | 3358        |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.003503967 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.05        |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 233         |
# |    n_updates            | 810         |
# |    policy_gradient_loss | 0.00582     |
# |    value_loss           | 368         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+04      |
# |    ep_rew_mean          | 1.58e+04      |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 83            |
# |    time_elapsed         | 3384          |
# |    total_timesteps      | 339968        |
# | train/                  |               |
# |    approx_kl            | 0.00020481952 |
# |    clip_fraction        | 0.0521        |
# |    clip_range           | 0.05          |
# |    entropy_loss         | -0.46         |
# |    explained_variance   | 0.224         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 265           |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -0.00164      |
# |    value_loss           | 544           |
# -------------------------------------------
# Eval num_timesteps=340000, episode_reward=6719.38 +/- 450.74
# Episode length: 10080.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+04     |
# |    mean_reward          | 6.72e+03     |
# | time/                   |              |
# |    total_timesteps      | 340000       |
# | train/                  |              |
# |    approx_kl            | 0.0006487408 |
# |    clip_fraction        | 0.065        |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 201          |
# |    n_updates            | 830          |
# |    policy_gradient_loss | 0.000405     |
# |    value_loss           | 435          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+04 |
# |    ep_rew_mean     | 1.58e+04 |
# | time/              |          |
# |    fps             | 98       |
# |    iterations      | 84       |
# |    time_elapsed    | 3491     |
# |    total_timesteps | 344064   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.58e+04     |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 85           |
# |    time_elapsed         | 3516         |
# |    total_timesteps      | 348160       |
# | train/                  |              |
# |    approx_kl            | 0.0002801171 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 294          |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 562          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+04     |
# |    ep_rew_mean          | 1.58e+04     |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 86           |
# |    time_elapsed         | 3542         |
# |    total_timesteps      | 352256       |
# | train/                  |              |
# |    approx_kl            | 8.758979e-05 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.05         |
# |    entropy_loss         | -0.434       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 178          |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 436          |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === Fin de l'entraînement PPO (safe) ===

# %%
# ======================================================
# Cellule 8 — Évaluation du modèle PPO finetuné (CORRIGÉE)
# ======================================================

def evaluate_agent(model, n_episodes=5, max_steps=10080):
    rewards = []

    for ep in range(n_episodes):
        env = WorkshopEnv()            # environnement brut
        obs, info = env.reset()
        total_r = 0.0

        for t in range(max_steps):

            mask = env.get_action_mask()

            # PREDICTION CORRECTE POUR MASKABLEPPO
            action, _ = model.predict(
                obs,                    # simple vecteur
                deterministic=True,
                action_masks=mask       # masque passé séparément
            )

            obs, r, terminated, truncated, info = env.step(action)
            total_r += r

            if terminated or truncated:
                break

        rewards.append(total_r)
        print(f"Episode {ep+1}/{n_episodes} — reward = {total_r:.2f}")

    rewards = np.array(rewards, dtype=np.float32)
    print(f"\nReward moyen sur {n_episodes} semaines : "
          f"{rewards.mean():.2f} ± {rewards.std():.2f}")

    return rewards, rewards.mean(), rewards.std()


# ========= CHARGEMENT DU BEST MODEL ==========
BEST_MODEL_PATH = "./ppo_safe_best_v4/best_model.zip"

try:
    best_model = MaskablePPO.load(BEST_MODEL_PATH, device="cuda")
    print(f"\nBest model chargé depuis : {BEST_MODEL_PATH}")
except Exception as e:
    print("\n⚠ Impossible de charger le best model, utilisation du model_ppo final.")
    best_model = model_ppo


# ========= ÉVALUATION ==========
print("\n=== Évaluation APRÈS PPO (policy finetunée) ===")
rewards_after, mean_after, std_after = evaluate_agent(best_model, n_episodes=5)
# Out:
# Best model chargé depuis : ./ppo_safe_best_v3/best_model.zip
#
# === Évaluation APRÈS PPO (policy finetunée) ===
# Episode 1/5 — reward = 13162.88
# Episode 2/5 — reward = 13904.78
# Episode 3/5 — reward = 13368.82
# Episode 4/5 — reward = 12942.38
# Episode 5/5 — reward = 13089.30
#
# Reward moyen sur 5 semaines : 13293.63 ± 335.08

# %%
# ======================================================
# cellule 9 : Sauvegarde propre du modèle PPO finetuné
# ======================================================

import os
from datetime import datetime

# Dossier de sauvegarde
SAVE_DIR = "ppo_final_model"
os.makedirs(SAVE_DIR, exist_ok=True)

# Nom du fichier = date + heure pour versioning automatique
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
MODEL_PATH = os.path.join(SAVE_DIR, f"ppo_finetuned_{timestamp}.zip")

# 1) Sauvegarde du modèle complet
best_model.save(MODEL_PATH)

# 2) Sauvegarde des hyperparamètres dans un fichier texte
with open(os.path.join(SAVE_DIR, "hyperparams_v4.txt"), "w") as f:
    f.write("=== PPO Finetuned Hyperparameters ===\n")
    f.write(f"learning_rate = {best_model.learning_rate}\n")
    f.write(f"clip_range    = constant schedule 0.05\n")
    f.write(f"ent_coef      = {best_model.ent_coef}\n")
    f.write(f"n_steps       = {best_model.n_steps}\n")
    f.write(f"batch_size    = {best_model.batch_size}\n")
    f.write(f"timestamp     = {timestamp}\n")

# 3) Message confirmation
print("======================================")
print("Modèle PPO finetuné sauvegardé avec succès !")
print("Chemin :", MODEL_PATH)
print("Hyperparamètres enregistrés dans : ppo_final_model/hyperparams_v4.txt")
print("======================================")
# Out:
# ======================================
# Modèle PPO finetuné sauvegardé avec succès !
# Chemin : ppo_final_model\ppo_finetuned_20251215_1607.zip
# Hyperparamètres enregistrés dans : ppo_final_model/hyperparams_v3.txt
# ======================================
