# %%
# Cellule 1 — Imports et configuration de base

import numpy as np
import torch
import gymnasium as gym
import json
import time

from gymnasium import spaces

from sb3_contrib import MaskablePPO
from env.workshop_env import WorkshopEnv

# === Historique des métriques DAgger ===
history = {
    "supervised_loss": [],   # perte moyenne par itération DAgger
    "reward_collect": [],    # reward élève pendant la phase de collecte
    "reward_eval": []        # reward élève en évaluation (7 jours)
}


# Pour rendre les choses un peu reproductibles
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
# Cellule 2 — Politique experte v4 (ajout pré-production) 
# compatible obs=23 variables + normalisation

from env.workshop_env import WorkshopEnv
import numpy as np

def expert_policy(obs: np.ndarray, env: WorkshopEnv) -> int:
    """
    Politique experte v4 :
    - identique à v3
    - + règle de pré-production :
        Si backlog_total == 0 et stock_produit < seuil_min, produire un petit lot
      (P2 prioritaire, sinon P1), seulement si machine libre et MP dispo.
    """

    # ============================================================
    # 1) Dé-normalisation des variables d'état
    # ============================================================

    time = float(obs[0]) * float(env.max_time)

    m1_busy = int(round(obs[1]))
    m1_time_left = float(obs[2]) * 100.0

    m2_busy = int(round(obs[3]))
    m2_time_left = float(obs[4]) * 100.0

    stock_raw = float(obs[5]) * float(env.raw_capacity)
    stock_p1 = float(obs[6]) * float(env.raw_capacity)
    stock_p2_inter = float(obs[7]) * float(env.raw_capacity)
    stock_p2 = float(obs[8]) * float(env.raw_capacity)

    next_delivery_cd = float(obs[9]) * 10080.0

    demande_p1 = float(obs[10]) * 1000.0
    demande_p2 = float(obs[11]) * 1000.0
    q_raw_incoming = float(obs[12]) * 1000.0

    m1_free = (m1_busy == 0)
    m2_free = (m2_busy == 0)

    backlog_p1 = max(demande_p1, 0.0)
    backlog_p2 = max(demande_p2, 0.0)
    backlog_total = backlog_p1 + backlog_p2

    # ============================================================
    # 2) Heuristique dynamique pour choisir k selon backlog
    # ============================================================

    def choose_k(backlog, k_max=5):
        k_max_int = int(k_max)
        if k_max_int < 1:
            return 0

        if backlog <= 5:       k = 1
        elif backlog <= 15:    k = 2
        elif backlog <= 30:    k = 3
        elif backlog <= 60:    k = 4
        else:                  k = 5

        k = min(k, k_max_int)
        return max(1, int(k))

    # ============================================================
    # 3) Politique de commande MP (version sécurisée)
    # ============================================================

    target_raw = min(env.raw_capacity, backlog_total + 10.0)
    current_pipeline = max(0.0, stock_raw + q_raw_incoming)
    missing = target_raw - current_pipeline

    if missing > 0:
        k_cmd = int(max(1, min(50, missing)))
        action_cmd = 149 + k_cmd  # 150 → 199
        if 0 <= action_cmd <= 200:
            return action_cmd

    # ============================================================
    # 3bis) NOUVELLE RÈGLE : pré-production si backlog_total == 0
    # ============================================================
    # Idée : garder un petit stock tampon quand l’atelier est “calme”.
    # IMPORTANT : on reste prudent (petit lot), et seulement si MP dispo.

    SEUIL_MIN_STOCK = 5.0     # <-- à ajuster (en unités "réelles" de ton échelle)
    LOT_PREFAB = 2            # <-- “un petit lot” : 1 ou 2 (reste modeste)

    if backlog_total <= 0.0:
        # Stock "produit fini total" (ici P1 + P2)
        stock_produit = stock_p1 + stock_p2

        if stock_produit < SEUIL_MIN_STOCK and stock_raw > 0:
            # 1) Si M1 libre : produire du P2 step1 (priorité P2)
            if m1_free:
                k_prefab = min(LOT_PREFAB, int(min(5, stock_raw)))
                if k_prefab >= 1:
                    action_p2_step1 = 49 + k_prefab   # 50 → 99
                    if 0 <= action_p2_step1 <= 200:
                        return action_p2_step1

            # 2) Sinon si M1 libre : produire du P1
            if m1_free:
                k_prefab = min(LOT_PREFAB, int(min(5, stock_raw)))
                if k_prefab >= 1:
                    action_p1 = k_prefab - 1          # 0 → 49
                    if 0 <= action_p1 <= 200:
                        return action_p1

    # ============================================================
    # 4) Priorité absolue : terminer STEP2_P2 si M2 libre
    # ============================================================

    if m2_free and stock_p2_inter > 0:
        k2 = choose_k(backlog_p2, k_max=min(5, stock_p2_inter))
        if k2 > 0:
            action_p2_step2 = 99 + k2  # 100 → 149
            if 0 <= action_p2_step2 <= 200:
                return action_p2_step2

    # ============================================================
    # 5) Priorité n°2 : produire STEP1_P2 si backlog P2 > 0
    # ============================================================

    if m1_free and backlog_p2 > 0 and stock_raw > 0:
        k1_p2 = choose_k(backlog_p2, k_max=min(5, stock_raw))
        if k1_p2 > 0:
            action_p2_step1 = 49 + k1_p2  # 50 → 99
            if 0 <= action_p2_step1 <= 200:
                return action_p2_step1

    # ============================================================
    # 6) Sinon, produire P1 si backlog P1 > 0
    # ============================================================

    if m1_free and backlog_p1 > 0 and stock_raw > 0:
        k1_p1 = choose_k(backlog_p1, k_max=min(5, stock_raw))
        if k1_p1 > 0:
            action_p1 = k1_p1 - 1         # 0 → 49
            if 0 <= action_p1 <= 200:
                return action_p1

    # ============================================================
    # 7) Sinon WAIT
    # ============================================================

    return 200

# %%
# Cellule 3 — Politique experte masquée + fonction d'épisode expert

def expert_policy_masked(env: WorkshopEnv, obs: np.ndarray) -> int:
    """
    Politique experte avec prise en compte du masque d'actions.
    Sécurisée : ne renvoie jamais une action hors [0, 200].
    """
    mask = env.get_action_mask().astype(bool)

    a = expert_policy(obs, env)  # action brute proposée par l'expert

    # Sécurité sur le type et la plage des indices
    if not isinstance(a, (int, np.integer)):
        a = 200
    elif a < 0 or a >= len(mask):
        a = 200

    # Si l'action est invalide selon le masque, on corrige
    if not mask[a]:
        # Priorité : WAIT si autorisé
        if mask[200]:
            return 200
        # Sinon, on prend la première action valide
        valid_actions = np.where(mask)[0]
        return int(valid_actions[0])

    return int(a)


def run_expert_episode(env: WorkshopEnv, max_steps: int = 10080):
    """
    Joue un épisode complet avec l'expert masqué.
    Renvoie :
      - obs_array : (T, 23)  # 23 features normalisées
      - act_array : (T,)
      - total_reward
      - nb_steps
    """
    obs, info = env.reset()
    obs_list = []
    act_list = []
    total_reward = 0.0

    for t in range(max_steps):
        action = expert_policy_masked(env, obs)
        obs_list.append(obs.copy())
        act_list.append(action)

        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        if terminated or truncated:
            break

    obs_array = np.stack(obs_list, axis=0)
    act_array = np.array(act_list, dtype=np.int64)

    return obs_array, act_array, total_reward, t + 1

# %%
# ============================================================
# CELLULE 4 — Générer un dataset initial de 100 épisodes experts
# ============================================================

import numpy as np

N_EXPERT_EPISODES = 100   # Nombre d'épisodes experts à générer

dagger_obs = []
dagger_actions = []
expert_rewards = []

print("=== Génération du dataset initial expert ===")

for ep in range(N_EXPERT_EPISODES):
    print(f"\n--- Episode expert {ep+1}/{N_EXPERT_EPISODES} ---")
    
    env_exp = WorkshopEnv()                 # nouvel environnement frais
    obs_ep, act_ep, rew_ep, length_ep = run_expert_episode(env_exp)

    # Stockage
    dagger_obs.append(obs_ep)
    dagger_actions.append(act_ep)
    expert_rewards.append(rew_ep)

    print(f"  ↳ Longueur épisode : {length_ep} steps")
    print(f"  ↳ Reward expert : {rew_ep:.2f}")

# Fusion des données des 100 épisodes
dagger_obs = np.vstack(dagger_obs)
dagger_actions = np.hstack(dagger_actions)

print("\n=== Dataset expert initial généré ===")
print("Taille dagger_obs :", dagger_obs.shape)
print("Taille dagger_actions :", dagger_actions.shape)
print(f"Reward moyen expert sur 100 épisodes : {np.mean(expert_rewards):.2f}")
print("===============================================")
# Out:
# === Génération du dataset initial expert ===
#
# --- Episode expert 1/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12812.92
#
# --- Episode expert 2/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13439.92
#
# --- Episode expert 3/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13075.12
#
# --- Episode expert 4/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13146.08
#
# --- Episode expert 5/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13415.74
#
# --- Episode expert 6/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12491.24
#
# --- Episode expert 7/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13345.72
#
# --- Episode expert 8/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13963.84
#
# --- Episode expert 9/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13295.06
#
# --- Episode expert 10/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12803.20
#
# --- Episode expert 11/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14179.72
#
# --- Episode expert 12/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13320.02
#
# --- Episode expert 13/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13143.74
#
# --- Episode expert 14/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13826.28
#
# --- Episode expert 15/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12993.64
#
# --- Episode expert 16/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13235.60
#
# --- Episode expert 17/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12989.84
#
# --- Episode expert 18/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13313.96
#
# --- Episode expert 19/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13194.84
#
# --- Episode expert 20/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13146.28
#
# --- Episode expert 21/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13301.64
#
# --- Episode expert 22/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12348.38
#
# --- Episode expert 23/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14164.82
#
# --- Episode expert 24/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13435.18
#
# --- Episode expert 25/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13940.38
#
# --- Episode expert 26/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13328.50
#
# --- Episode expert 27/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12928.20
#
# --- Episode expert 28/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13814.46
#
# --- Episode expert 29/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12647.74
#
# --- Episode expert 30/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13898.40
#
# --- Episode expert 31/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13357.64
#
# --- Episode expert 32/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13347.52
#
# --- Episode expert 33/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14128.78
#
# --- Episode expert 34/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13933.00
#
# --- Episode expert 35/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13022.02
#
# --- Episode expert 36/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14526.48
#
# --- Episode expert 37/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13402.46
#
# --- Episode expert 38/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13374.04
#
# --- Episode expert 39/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12994.26
#
# --- Episode expert 40/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14172.14
#
# --- Episode expert 41/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12817.14
#
# --- Episode expert 42/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13182.34
#
# --- Episode expert 43/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14161.12
#
# --- Episode expert 44/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13542.02
#
# --- Episode expert 45/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13244.40
#
# --- Episode expert 46/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13130.84
#
# --- Episode expert 47/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13294.90
#
# --- Episode expert 48/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12863.66
#
# --- Episode expert 49/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14161.96
#
# --- Episode expert 50/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13719.10
#
# --- Episode expert 51/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12854.48
#
# --- Episode expert 52/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13184.66
#
# --- Episode expert 53/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12821.50
#
# --- Episode expert 54/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12676.66
#
# --- Episode expert 55/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12668.02
#
# --- Episode expert 56/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13196.34
#
# --- Episode expert 57/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13409.94
#
# --- Episode expert 58/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13097.12
#
# --- Episode expert 59/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13691.92
#
# --- Episode expert 60/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13999.24
#
# --- Episode expert 61/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12976.12
#
# --- Episode expert 62/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13178.44
#
# --- Episode expert 63/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13499.04
#
# --- Episode expert 64/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13104.56
#
# --- Episode expert 65/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13408.44
#
# --- Episode expert 66/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14025.56
#
# --- Episode expert 67/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13208.06
#
# --- Episode expert 68/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13944.92
#
# --- Episode expert 69/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13086.14
#
# --- Episode expert 70/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13176.00
#
# --- Episode expert 71/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13943.74
#
# --- Episode expert 72/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12631.26
#
# --- Episode expert 73/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13450.76
#
# --- Episode expert 74/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13116.42
#
# --- Episode expert 75/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13423.54
#
# --- Episode expert 76/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13388.78
#
# --- Episode expert 77/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13159.58
#
# --- Episode expert 78/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13115.32
#
# --- Episode expert 79/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13124.04
#
# --- Episode expert 80/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13265.54
#
# --- Episode expert 81/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13871.04
#
# --- Episode expert 82/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14034.82
#
# --- Episode expert 83/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13657.64
#
# --- Episode expert 84/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13179.74
#
# --- Episode expert 85/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13475.96
#
# --- Episode expert 86/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13335.96
#
# --- Episode expert 87/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13236.82
#
# --- Episode expert 88/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13227.48
#
# --- Episode expert 89/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13746.46
#
# --- Episode expert 90/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 12829.04
#
# --- Episode expert 91/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13521.42
#
# --- Episode expert 92/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13268.46
#
# --- Episode expert 93/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13455.62
#
# --- Episode expert 94/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 14619.26
#
# --- Episode expert 95/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13331.76
#
# --- Episode expert 96/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13791.98
#
# --- Episode expert 97/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13202.78
#
# --- Episode expert 98/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13665.20
#
# --- Episode expert 99/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13297.34
#
# --- Episode expert 100/100 ---
#   ↳ Longueur épisode : 10080 steps
#   ↳ Reward expert : 13478.66
#
# === Dataset expert initial généré ===
# Taille dagger_obs : (1008000, 23)
# Taille dagger_actions : (1008000,)
# Reward moyen expert sur 100 épisodes : 13373.70
# ===============================================

# %%
# Cellule 5 — Environnement avec ActionMasker + Modèle MaskablePPO (CPU)

import gymnasium as gym
from sb3_contrib.common.wrappers import ActionMasker

# 1) Fonction de masquage (appelée automatiquement par ActionMasker)
def mask_fn(env):
    return env.get_action_mask()

# 2) Environnement enveloppé
env_student = ActionMasker(WorkshopEnv(), mask_fn)

# 3) Modèle MaskablePPO — FORCÉ SUR CPU
from sb3_contrib import MaskablePPO

model_student = MaskablePPO(
    policy="MlpPolicy",
    env=env_student,
    verbose=1,
    device="cpu",              # <<< ICI : CPU, plus "cuda"
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    n_steps=4096,
    batch_size=512,
    clip_range=0.2,
    ent_coef=0.01,
    max_grad_norm=0.5,
    tensorboard_log="./tb_dagger_hybrid"
)

print("Modèle élève initialisé (MaskablePPO + CPU + ActionMasker OK).")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Modèle élève initialisé (MaskablePPO + CPU + ActionMasker OK).

# %%
#  CELLULE 6 — Entraînement supervisé DAgger (VERSION LÉGÈRE) 

import torch
import torch.nn as nn
import torch.optim as optim

def train_student_supervised(model, obs_array, act_array, epochs=5, batch_size=256):
    """
    Entraînement supervisé du student :
    Il apprend à imiter l'expert sur le buffer DAgger.

    obs_array : (N, 23)
    act_array : (N,)

    VERSION LÉGÈRE :
    - on limite le nombre d'exemples utilisés à MAX_TRAIN_SAMPLES
      pour éviter de saturer le CPU / la RAM.
    """

    # 0) Limiter la taille du dataset pour rester "safe"
    MAX_TRAIN_SAMPLES = 12000  # à ajuster, mais déjà bien plus léger que 30000

    N_total = len(obs_array)
    if N_total > MAX_TRAIN_SAMPLES:
        # On tire un sous-échantillon aléatoire sans remplacement
        idx = np.random.choice(N_total, size=MAX_TRAIN_SAMPLES, replace=False)
        obs_array = obs_array[idx]
        act_array = act_array[idx]
        print(f"  → Sous-échantillonnage du buffer DAgger : {N_total} → {MAX_TRAIN_SAMPLES} exemples")
    else:
        print(f"  → Utilisation de tous les exemples : {N_total}")

    # 1) Le modèle MaskablePPO tourne en CPU → on aligne l'entraînement dessus
    device = model.policy.device
    policy = model.policy.to(device)

    # 2) Conversion en tenseurs
    X = torch.tensor(obs_array, dtype=torch.float32, device=device)
    y = torch.tensor(act_array, dtype=torch.long, device=device)

    # 3) Sécurité : les actions doivent être dans [0, action_space.n]
    max_action = policy.action_space.n - 1
    y = torch.clamp(y, 0, max_action)

    # 4) Optimiseur + fonction de perte
    optimizer = optim.Adam(policy.parameters(), lr=1e-4)
    loss_fn = nn.CrossEntropyLoss()

    N = len(X)
    nb_batches = (N + batch_size - 1) // batch_size

    print(f"  → Entraînement supervisé sur {N} exemples ({nb_batches} batches)")

    avg_epoch_loss = 0.0

    # 5) Entraînement sur plusieurs epochs
    for epoch in range(epochs):
        perm = torch.randperm(N, device=device)
        Xb = X[perm]
        yb = y[perm]

        total_loss = 0.0

        for i in range(nb_batches):
            start = i * batch_size
            end = min(start + batch_size, N)

            xb_i = Xb[start:end]
            yb_i = yb[start:end]

            # 6) Forward pass (architecture PPO)
            features = policy.extract_features(xb_i)             # encode l'état
            pi_latent, _ = policy.mlp_extractor(features)        # réseau intermédiaire
            logits = policy.action_net(pi_latent)                # logits actions

            loss = loss_fn(logits, yb_i)

            # 7) Backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        epoch_loss = total_loss / nb_batches
        avg_epoch_loss = epoch_loss

        print(f"    Epoch {epoch+1}/{epochs} — loss = {epoch_loss:.4f}")

    print("  ✓ Entraînement supervisé terminé.\n")
    return avg_epoch_loss

# %%
# Cellule 7 — Test de l'élève sur une semaine (version MlpPolicy)

def run_student_episode(env, model, max_steps: int = 10080):
    obs, info = env.reset()
    total_reward = 0.0

    for t in range(max_steps):
        # On donne simplement l'observation brute au modèle
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        if terminated or truncated:
            break

    return total_reward, t + 1

# %%
# ============================================================
# CELLULE 8 — Collecte des données DAgger 
# ============================================================

def collect_dagger_data_from_student(model, max_steps=10080):
    """
    L'élève joue un épisode complet.
    L'expert corrige chaque action.
    On renvoie :
    - obs_list  : toutes les observations rencontrées
    - act_list  : actions expertes correspondantes
    - total_reward_student : reward cumulé du student
    - nb_steps_student     : nombre de steps joués
    """

    env = WorkshopEnv()
    obs, info = env.reset()

    obs_list = []
    act_list = []

    total_reward = 0.0

    for t in range(max_steps):

        #  Très important : récupérer le MASQUE
        mask = env.get_action_mask()

        #  predict() DOIT recevoir action_masks pour éviter actions hors borne
        action_student, _ = model.predict(
            obs,
            deterministic=True,
            action_masks=mask
        )

        # L'expert corrige l'action
        action_expert = expert_policy_masked(env, obs)

        obs_list.append(obs.copy())
        act_list.append(action_expert)

        obs, reward, terminated, truncated, info = env.step(action_student)
        total_reward += reward

        if terminated or truncated:
            break

    return (
        np.array(obs_list, dtype=np.float32),
        np.array(act_list, dtype=np.int64),
        float(total_reward),
        t + 1
    )

# %%
# Cellule 9 — Une itération DAgger imitation-seule (SANS PPO)

def dagger_hybrid_iteration(
    model,
    dagger_obs,
    dagger_actions,
    supervised_epochs: int = 3,
    rl_timesteps: int = 10_000
):
    """
    VERSION DIAGNOSTIC : imitation supervisée SEULE
    (on désactive PPO pour voir si le modèle apprend réellement les actions expertes).
    Cette version enregistre les métriques dans le dict global `history`.
    """

    print("\n===== Phase 1 : Imitation supervisée sur buffer DAgger =====")
    loss_value = train_student_supervised(model, dagger_obs, dagger_actions, epochs=supervised_epochs)
    history["supervised_loss"].append(loss_value)

    print("\n===== Phase 2 : (désactivée) =====")
    print("⚠ PPO désactivé volontairement pour test de diagnostic.")

    print("\n===== Phase 3 : Collecte DAgger (élève + expert) =====")
    new_obs, new_actions, R_student, steps_student = collect_dagger_data_from_student(model)
    history["reward_collect"].append(R_student)

    print(f"Reward élève pendant collecte DAgger : {R_student:.2f} sur {steps_student} steps")

    # Agrégation au buffer
    dagger_obs = np.vstack([dagger_obs, new_obs])
    dagger_actions = np.concatenate([dagger_actions, new_actions])

    print("Taille du buffer DAgger après agrégation :", dagger_obs.shape)

    return dagger_obs, dagger_actions

# %%
# ======================= CELLULE 10 — DAgger PUR (10080 STEPS) =======================

start_time = time.time()

# Hyperparamètres
N_ITERS            = 80         # itérations DAgger 
SUPERVISED_EPOCHS  = 3
BATCH_SIZE         = 512
EPISODE_STEPS      = 10080     # 1 semaine = 10080 steps
MAX_BUFFER         = 30_000    # borne RAM (à ajuster selon ta machine)

history = {
    "supervised_loss": [],
    "reward_collect": [],
    "reward_eval": []
}

print("\n=== BOUCLE DAgger — VERSION PURE (Épisodes complets 10080 steps) ===\n")


for it in range(1, N_ITERS + 1):

    print(f"\n=========== Iteration {it}/{N_ITERS} DAgger ===========")


    # ----------------------------------------------------------
    # PHASE 1 — Imitation supervisée sur le buffer actuel
    # ----------------------------------------------------------
    print("\n[Phase 1] Entraînement supervisé (imitation expert)")

    avg_loss = train_student_supervised(
        model_student,
        dagger_obs,
        dagger_actions,
        epochs=SUPERVISED_EPOCHS,
        batch_size=BATCH_SIZE
    )

    history["supervised_loss"].append(avg_loss)
    print(f"  → Loss moyenne = {avg_loss:.4f}")


    # ----------------------------------------------------------
    # PHASE 2 — Collecte d'une SEMAINE complète avec l'élève
    #            + corrections de l'expert (DAgger pur)
    # ----------------------------------------------------------
    print("\n[Phase 2] Collecte DAgger (1 semaine simulée)")

    new_obs, new_actions, R_collect, steps = collect_dagger_data_from_student(
        model_student,
        max_steps=EPISODE_STEPS
    )

    print(f"  → Reward élève sur 10080 steps : {R_collect:.2f}")
    print(f"  → Steps joués : {steps}")

    history["reward_collect"].append(R_collect)

    # Ajout au buffer
    dagger_obs = np.vstack([dagger_obs, new_obs])
    dagger_actions = np.hstack([dagger_actions, new_actions])

    # Sécurité mémoire : on ne garde que les MAX_BUFFER derniers exemples
    if dagger_obs.shape[0] > MAX_BUFFER:
        dagger_obs = dagger_obs[-MAX_BUFFER:]
        dagger_actions = dagger_actions[-MAX_BUFFER:]

    print("  → Taille du buffer DAgger :", dagger_obs.shape)


    # ----------------------------------------------------------
    # PHASE 3 — Évaluation de l'élève sur 1 semaine complète
    # ----------------------------------------------------------
    print("\n[Phase 3] Évaluation (1 semaine complète, 10080 steps)")

    env_eval = WorkshopEnv()
    obs, info = env_eval.reset()
    R_eval = 0

    for _ in range(EPISODE_STEPS):

        mask = env_eval.get_action_mask()
        action, _ = model_student.predict(obs, deterministic=True, action_masks=mask)

        obs, r, terminated, truncated, _ = env_eval.step(action)
        R_eval += r

        if terminated or truncated:
            break

    history["reward_eval"].append(R_eval)

    print(f"  → Reward élève en évaluation (10080 steps) : {R_eval:.2f}")
   
    # Sauvegarde de l'historique à chaque itération (sécurisé)
    with open("history_dagger.json", "w") as f:
        json.dump(history, f)

    print(f"✓ Historique partiel sauvegardé (itération {it})")

    # Sauvegarde du modèle élève pour cette itération
    model_student.save(f"student_dagger_expertv4_iter_{it}.zip")

    # Sauvegarde du dataset toutes les 5 itérations
    if it % 5 == 0:
        np.save(f"dagger_obs_iter_{it}.npy", dagger_obs)
        np.save(f"dagger_actions_iter_{it}.npy", dagger_actions)
        print(f"✓ Dataset sauvegardé (itération {it})")

    # Chrono simple
    elapsed = time.time() - start_time
    print(f" Temps écoulé : {elapsed/60:.1f} min")



print("\n=== FIN DU DAgger — VERSION ÉPISODES 10080 STEPS ===\n")
# Sauvegarde finale une fois le DAgger terminé
model_student.save("student_dagger_expertv4_final.zip")
print("\n✓ Modèle final sauvegardé : student_dagger_expertv4_final.zip")
# Out:
# === BOUCLE DAgger — VERSION PURE (Épisodes complets 10080 steps) ===
#
#
# =========== Iteration 1/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 1008000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 5.2556
#     Epoch 2/3 — loss = 5.1397
#     Epoch 3/3 — loss = 4.9785
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 4.9785
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5877.82
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6138.14
# ✓ Historique partiel sauvegardé (itération 1)
#  Temps écoulé : 0.5 min
#
# =========== Iteration 2/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 4.9448
#     Epoch 2/3 — loss = 4.7639
#     Epoch 3/3 — loss = 4.5495
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 4.5495
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -6292.82
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6210.02
# ✓ Historique partiel sauvegardé (itération 2)
#  Temps écoulé : 1.1 min
#
# =========== Iteration 3/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 4.5303
#     Epoch 2/3 — loss = 4.3036
#     Epoch 3/3 — loss = 4.0573
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 4.0573
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5916.44
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6022.80
# ✓ Historique partiel sauvegardé (itération 3)
#  Temps écoulé : 1.6 min
#
# =========== Iteration 4/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 4.0393
#     Epoch 2/3 — loss = 3.7699
#     Epoch 3/3 — loss = 3.4852
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.4852
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -6196.76
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6093.00
# ✓ Historique partiel sauvegardé (itération 4)
#  Temps écoulé : 2.0 min
#
# =========== Iteration 5/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.1830
#     Epoch 2/3 — loss = 2.8911
#     Epoch 3/3 — loss = 2.6012
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.6012
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -397462.46
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -397057.38
# ✓ Historique partiel sauvegardé (itération 5)
# ✓ Dataset sauvegardé (itération 5)
#  Temps écoulé : 2.6 min
#
# =========== Iteration 6/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.3345
#     Epoch 2/3 — loss = 3.0899
#     Epoch 3/3 — loss = 2.8707
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.8707
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -397291.42
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -396986.94
# ✓ Historique partiel sauvegardé (itération 6)
#  Temps écoulé : 3.1 min
#
# =========== Iteration 7/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.7107
#     Epoch 2/3 — loss = 3.5076
#     Epoch 3/3 — loss = 3.3074
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.3074
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -397024.80
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -397639.22
# ✓ Historique partiel sauvegardé (itération 7)
#  Temps écoulé : 3.7 min
#
# =========== Iteration 8/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 4.0943
#     Epoch 2/3 — loss = 3.8229
#     Epoch 3/3 — loss = 3.5482
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.5482
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -396801.94
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -397056.60
# ✓ Historique partiel sauvegardé (itération 8)
#  Temps écoulé : 4.3 min
#
# =========== Iteration 9/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.2765
#     Epoch 2/3 — loss = 3.0101
#     Epoch 3/3 — loss = 2.7526
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.7526
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -396875.00
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -397187.80
# ✓ Historique partiel sauvegardé (itération 9)
#  Temps écoulé : 4.9 min
#
# =========== Iteration 10/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.5048
#     Epoch 2/3 — loss = 2.2698
#     Epoch 3/3 — loss = 2.0544
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.0544
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -396795.82
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -397104.86
# ✓ Historique partiel sauvegardé (itération 10)
# ✓ Dataset sauvegardé (itération 10)
#  Temps écoulé : 5.4 min
#
# =========== Iteration 11/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.8748
#     Epoch 2/3 — loss = 1.6890
#     Epoch 3/3 — loss = 1.5253
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.5253
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -384465.64
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -384001.66
# ✓ Historique partiel sauvegardé (itération 11)
#  Temps écoulé : 6.0 min
#
# =========== Iteration 12/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.0414
#     Epoch 2/3 — loss = 2.9103
#     Epoch 3/3 — loss = 2.7865
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.7865
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -384190.42
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -384381.54
# ✓ Historique partiel sauvegardé (itération 12)
#  Temps écoulé : 6.5 min
#
# =========== Iteration 13/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 4.2287
#     Epoch 2/3 — loss = 4.0291
#     Epoch 3/3 — loss = 3.8325
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.8325
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -384155.06
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -384043.50
# ✓ Historique partiel sauvegardé (itération 13)
#  Temps écoulé : 7.0 min
#
# =========== Iteration 14/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 4.8669
#     Epoch 2/3 — loss = 4.5638
#     Epoch 3/3 — loss = 4.2690
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 4.2690
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -384130.16
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -384275.32
# ✓ Historique partiel sauvegardé (itération 14)
#  Temps écoulé : 7.6 min
#
# =========== Iteration 15/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.9940
#     Epoch 2/3 — loss = 3.7207
#     Epoch 3/3 — loss = 3.4722
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.4722
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -384230.12
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -384384.80
# ✓ Historique partiel sauvegardé (itération 15)
# ✓ Dataset sauvegardé (itération 15)
#  Temps écoulé : 8.1 min
#
# =========== Iteration 16/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.2398
#     Epoch 2/3 — loss = 3.0024
#     Epoch 3/3 — loss = 2.7643
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.7643
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -358875.48
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -358571.90
# ✓ Historique partiel sauvegardé (itération 16)
#  Temps écoulé : 8.7 min
#
# =========== Iteration 17/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.2248
#     Epoch 2/3 — loss = 2.9981
#     Epoch 3/3 — loss = 2.7749
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.7749
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -359255.22
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -358853.88
# ✓ Historique partiel sauvegardé (itération 17)
#  Temps écoulé : 9.2 min
#
# =========== Iteration 18/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.1929
#     Epoch 2/3 — loss = 2.9824
#     Epoch 3/3 — loss = 2.7883
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.7883
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -358688.84
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -359326.98
# ✓ Historique partiel sauvegardé (itération 18)
#  Temps écoulé : 9.7 min
#
# =========== Iteration 19/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.0987
#     Epoch 2/3 — loss = 2.7990
#     Epoch 3/3 — loss = 2.4996
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.4996
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -126356.62
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -126861.72
# ✓ Historique partiel sauvegardé (itération 19)
#  Temps écoulé : 10.3 min
#
# =========== Iteration 20/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.1485
#     Epoch 2/3 — loss = 1.8810
#     Epoch 3/3 — loss = 1.6331
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.6331
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5768.30
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6170.34
# ✓ Historique partiel sauvegardé (itération 20)
# ✓ Dataset sauvegardé (itération 20)
#  Temps écoulé : 10.7 min
#
# =========== Iteration 21/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.6461
#     Epoch 2/3 — loss = 1.4788
#     Epoch 3/3 — loss = 1.3500
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.3500
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5680.78
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6116.88
# ✓ Historique partiel sauvegardé (itération 21)
#  Temps écoulé : 11.2 min
#
# =========== Iteration 22/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.4954
#     Epoch 2/3 — loss = 1.3834
#     Epoch 3/3 — loss = 1.2973
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.2973
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -139360.64
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -140048.06
# ✓ Historique partiel sauvegardé (itération 22)
#  Temps écoulé : 11.8 min
#
# =========== Iteration 23/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.7566
#     Epoch 2/3 — loss = 1.6194
#     Epoch 3/3 — loss = 1.5016
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.5016
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -263831.56
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -264121.08
# ✓ Historique partiel sauvegardé (itération 23)
#  Temps écoulé : 12.3 min
#
# =========== Iteration 24/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.7417
#     Epoch 2/3 — loss = 1.5902
#     Epoch 3/3 — loss = 1.4657
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.4657
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -274413.58
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -274374.90
# ✓ Historique partiel sauvegardé (itération 24)
#  Temps écoulé : 12.9 min
#
# =========== Iteration 25/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.9572
#     Epoch 2/3 — loss = 1.8161
#     Epoch 3/3 — loss = 1.7106
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.7106
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -248650.36
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -249048.62
# ✓ Historique partiel sauvegardé (itération 25)
# ✓ Dataset sauvegardé (itération 25)
#  Temps écoulé : 13.4 min
#
# =========== Iteration 26/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.1739
#     Epoch 2/3 — loss = 2.0715
#     Epoch 3/3 — loss = 1.9939
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.9939
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -79765.46
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -80109.94
# ✓ Historique partiel sauvegardé (itération 26)
#  Temps écoulé : 13.9 min
#
# =========== Iteration 27/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.2569
#     Epoch 2/3 — loss = 2.0882
#     Epoch 3/3 — loss = 1.9459
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.9459
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -6161.20
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6052.26
# ✓ Historique partiel sauvegardé (itération 27)
#  Temps écoulé : 14.5 min
#
# =========== Iteration 28/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.9819
#     Epoch 2/3 — loss = 1.8852
#     Epoch 3/3 — loss = 1.8048
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.8048
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -66602.10
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -66514.42
# ✓ Historique partiel sauvegardé (itération 28)
#  Temps écoulé : 15.0 min
#
# =========== Iteration 29/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.7320
#     Epoch 2/3 — loss = 1.6551
#     Epoch 3/3 — loss = 1.5878
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.5878
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -187384.60
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -186921.38
# ✓ Historique partiel sauvegardé (itération 29)
#  Temps écoulé : 15.5 min
#
# =========== Iteration 30/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.6953
#     Epoch 2/3 — loss = 1.5979
#     Epoch 3/3 — loss = 1.5261
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.5261
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -155654.08
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -155586.50
# ✓ Historique partiel sauvegardé (itération 30)
# ✓ Dataset sauvegardé (itération 30)
#  Temps écoulé : 16.1 min
#
# =========== Iteration 31/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.5984
#     Epoch 2/3 — loss = 1.4631
#     Epoch 3/3 — loss = 1.3451
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.3451
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -12756.12
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -12640.72
# ✓ Historique partiel sauvegardé (itération 31)
#  Temps écoulé : 16.6 min
#
# =========== Iteration 32/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.6475
#     Epoch 2/3 — loss = 1.5074
#     Epoch 3/3 — loss = 1.3929
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.3929
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5982.86
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6301.68
# ✓ Historique partiel sauvegardé (itération 32)
#  Temps écoulé : 17.1 min
#
# =========== Iteration 33/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.7042
#     Epoch 2/3 — loss = 1.6155
#     Epoch 3/3 — loss = 1.5519
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.5519
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -9101.54
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -9203.28
# ✓ Historique partiel sauvegardé (itération 33)
#  Temps écoulé : 17.7 min
#
# =========== Iteration 34/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.9532
#     Epoch 2/3 — loss = 1.8611
#     Epoch 3/3 — loss = 1.7832
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.7832
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -74970.06
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -74327.56
# ✓ Historique partiel sauvegardé (itération 34)
#  Temps écoulé : 18.2 min
#
# =========== Iteration 35/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.8226
#     Epoch 2/3 — loss = 2.6906
#     Epoch 3/3 — loss = 2.5569
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.5569
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -88676.88
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -88325.02
# ✓ Historique partiel sauvegardé (itération 35)
# ✓ Dataset sauvegardé (itération 35)
#  Temps écoulé : 18.8 min
#
# =========== Iteration 36/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.6955
#     Epoch 2/3 — loss = 2.5398
#     Epoch 3/3 — loss = 2.3959
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.3959
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -4887.46
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -4598.00
# ✓ Historique partiel sauvegardé (itération 36)
#  Temps écoulé : 19.3 min
#
# =========== Iteration 37/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.5349
#     Epoch 2/3 — loss = 3.3438
#     Epoch 3/3 — loss = 3.1873
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.1873
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5806.38
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -5952.98
# ✓ Historique partiel sauvegardé (itération 37)
#  Temps écoulé : 19.8 min
#
# =========== Iteration 38/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.7276
#     Epoch 2/3 — loss = 3.5736
#     Epoch 3/3 — loss = 3.4371
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.4371
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -6010.44
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6263.74
# ✓ Historique partiel sauvegardé (itération 38)
#  Temps écoulé : 20.3 min
#
# =========== Iteration 39/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.5386
#     Epoch 2/3 — loss = 3.4155
#     Epoch 3/3 — loss = 3.2898
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.2898
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5983.12
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6138.12
# ✓ Historique partiel sauvegardé (itération 39)
#  Temps écoulé : 20.8 min
#
# =========== Iteration 40/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.8257
#     Epoch 2/3 — loss = 3.6445
#     Epoch 3/3 — loss = 3.4912
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.4912
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -3612.46
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -3763.72
# ✓ Historique partiel sauvegardé (itération 40)
# ✓ Dataset sauvegardé (itération 40)
#  Temps écoulé : 21.3 min
#
# =========== Iteration 41/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.5979
#     Epoch 2/3 — loss = 3.4748
#     Epoch 3/3 — loss = 3.3558
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.3558
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -196.98
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -218.78
# ✓ Historique partiel sauvegardé (itération 41)
#  Temps écoulé : 21.8 min
#
# =========== Iteration 42/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 4.1211
#     Epoch 2/3 — loss = 3.9894
#     Epoch 3/3 — loss = 3.8595
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.8595
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 14169.74
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 12478.46
# ✓ Historique partiel sauvegardé (itération 42)
#  Temps écoulé : 22.2 min
#
# =========== Iteration 43/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.3056
#     Epoch 2/3 — loss = 3.2072
#     Epoch 3/3 — loss = 3.1328
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.1328
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -716.74
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -976.98
# ✓ Historique partiel sauvegardé (itération 43)
#  Temps écoulé : 22.7 min
#
# =========== Iteration 44/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.9408
#     Epoch 2/3 — loss = 3.7960
#     Epoch 3/3 — loss = 3.6694
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.6694
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -4659.24
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -4411.68
# ✓ Historique partiel sauvegardé (itération 44)
#  Temps écoulé : 23.2 min
#
# =========== Iteration 45/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.5474
#     Epoch 2/3 — loss = 3.4117
#     Epoch 3/3 — loss = 3.3027
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.3027
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -6554.90
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6327.66
# ✓ Historique partiel sauvegardé (itération 45)
# ✓ Dataset sauvegardé (itération 45)
#  Temps écoulé : 23.7 min
#
# =========== Iteration 46/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.3871
#     Epoch 2/3 — loss = 3.2559
#     Epoch 3/3 — loss = 3.1392
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.1392
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -17098.70
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -17019.40
# ✓ Historique partiel sauvegardé (itération 46)
#  Temps écoulé : 24.2 min
#
# =========== Iteration 47/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.4814
#     Epoch 2/3 — loss = 2.3521
#     Epoch 3/3 — loss = 2.2669
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.2669
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -279.56
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -1110.50
# ✓ Historique partiel sauvegardé (itération 47)
#  Temps écoulé : 24.7 min
#
# =========== Iteration 48/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.3010
#     Epoch 2/3 — loss = 2.1795
#     Epoch 3/3 — loss = 2.0720
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.0720
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 14931.50
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 15252.28
# ✓ Historique partiel sauvegardé (itération 48)
#  Temps écoulé : 25.3 min
#
# =========== Iteration 49/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.8576
#     Epoch 2/3 — loss = 2.7363
#     Epoch 3/3 — loss = 2.6424
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.6424
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 12191.00
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 12168.58
# ✓ Historique partiel sauvegardé (itération 49)
#  Temps écoulé : 25.7 min
#
# =========== Iteration 50/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.2692
#     Epoch 2/3 — loss = 3.1740
#     Epoch 3/3 — loss = 3.1034
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.1034
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 11929.80
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 11071.80
# ✓ Historique partiel sauvegardé (itération 50)
# ✓ Dataset sauvegardé (itération 50)
#  Temps écoulé : 26.2 min
#
# =========== Iteration 51/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.3087
#     Epoch 2/3 — loss = 3.2196
#     Epoch 3/3 — loss = 3.1487
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.1487
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 10737.54
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 9702.90
# ✓ Historique partiel sauvegardé (itération 51)
#  Temps écoulé : 26.7 min
#
# =========== Iteration 52/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.5349
#     Epoch 2/3 — loss = 3.4505
#     Epoch 3/3 — loss = 3.3831
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.3831
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 5803.60
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 5551.84
# ✓ Historique partiel sauvegardé (itération 52)
#  Temps écoulé : 27.2 min
#
# =========== Iteration 53/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.4393
#     Epoch 2/3 — loss = 3.3577
#     Epoch 3/3 — loss = 3.2856
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.2856
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 9528.96
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 9898.46
# ✓ Historique partiel sauvegardé (itération 53)
#  Temps écoulé : 27.7 min
#
# =========== Iteration 54/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.2291
#     Epoch 2/3 — loss = 3.1335
#     Epoch 3/3 — loss = 3.0527
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.0527
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 10027.80
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 8725.24
# ✓ Historique partiel sauvegardé (itération 54)
#  Temps écoulé : 28.2 min
#
# =========== Iteration 55/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.5799
#     Epoch 2/3 — loss = 2.4638
#     Epoch 3/3 — loss = 2.3687
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.3687
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 12705.70
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 13217.40
# ✓ Historique partiel sauvegardé (itération 55)
# ✓ Dataset sauvegardé (itération 55)
#  Temps écoulé : 28.7 min
#
# =========== Iteration 56/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.1965
#     Epoch 2/3 — loss = 2.0611
#     Epoch 3/3 — loss = 1.9567
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.9567
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5378.72
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -5569.18
# ✓ Historique partiel sauvegardé (itération 56)
#  Temps écoulé : 29.2 min
#
# =========== Iteration 57/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.8660
#     Epoch 2/3 — loss = 1.7344
#     Epoch 3/3 — loss = 1.6322
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.6322
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5908.06
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6239.28
# ✓ Historique partiel sauvegardé (itération 57)
#  Temps écoulé : 29.7 min
#
# =========== Iteration 58/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.9338
#     Epoch 2/3 — loss = 2.7409
#     Epoch 3/3 — loss = 2.5655
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.5655
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 12019.78
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 12843.96
# ✓ Historique partiel sauvegardé (itération 58)
#  Temps écoulé : 30.2 min
#
# =========== Iteration 59/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.6485
#     Epoch 2/3 — loss = 3.4387
#     Epoch 3/3 — loss = 3.2663
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 3.2663
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 12084.20
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 12412.54
# ✓ Historique partiel sauvegardé (itération 59)
#  Temps écoulé : 30.7 min
#
# =========== Iteration 60/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.2230
#     Epoch 2/3 — loss = 3.0835
#     Epoch 3/3 — loss = 2.9414
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.9414
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 10607.04
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 10684.64
# ✓ Historique partiel sauvegardé (itération 60)
# ✓ Dataset sauvegardé (itération 60)
#  Temps écoulé : 31.2 min
#
# =========== Iteration 61/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.8965
#     Epoch 2/3 — loss = 2.7864
#     Epoch 3/3 — loss = 2.6935
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.6935
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -5948.76
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -5631.94
# ✓ Historique partiel sauvegardé (itération 61)
#  Temps écoulé : 31.7 min
#
# =========== Iteration 62/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.3967
#     Epoch 2/3 — loss = 2.3151
#     Epoch 3/3 — loss = 2.2523
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.2523
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -6060.16
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6227.56
# ✓ Historique partiel sauvegardé (itération 62)
#  Temps écoulé : 32.2 min
#
# =========== Iteration 63/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.7993
#     Epoch 2/3 — loss = 2.6836
#     Epoch 3/3 — loss = 2.5908
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.5908
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -6350.78
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -6865.12
# ✓ Historique partiel sauvegardé (itération 63)
#  Temps écoulé : 32.8 min
#
# =========== Iteration 64/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.7193
#     Epoch 2/3 — loss = 2.6018
#     Epoch 3/3 — loss = 2.4965
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.4965
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -10189.42
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -10761.86
# ✓ Historique partiel sauvegardé (itération 64)
#  Temps écoulé : 33.2 min
#
# =========== Iteration 65/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.7598
#     Epoch 2/3 — loss = 2.5910
#     Epoch 3/3 — loss = 2.4491
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.4491
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -18687.46
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -18083.86
# ✓ Historique partiel sauvegardé (itération 65)
# ✓ Dataset sauvegardé (itération 65)
#  Temps écoulé : 33.7 min
#
# =========== Iteration 66/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.2923
#     Epoch 2/3 — loss = 2.0759
#     Epoch 3/3 — loss = 1.8864
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.8864
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 10545.40
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 10653.34
# ✓ Historique partiel sauvegardé (itération 66)
#  Temps écoulé : 34.2 min
#
# =========== Iteration 67/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.1941
#     Epoch 2/3 — loss = 2.0670
#     Epoch 3/3 — loss = 1.9613
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.9613
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 10981.34
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 11365.48
# ✓ Historique partiel sauvegardé (itération 67)
#  Temps écoulé : 34.7 min
#
# =========== Iteration 68/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.5250
#     Epoch 2/3 — loss = 2.4235
#     Epoch 3/3 — loss = 2.3409
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.3409
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 6163.18
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 6886.22
# ✓ Historique partiel sauvegardé (itération 68)
#  Temps écoulé : 35.2 min
#
# =========== Iteration 69/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.5876
#     Epoch 2/3 — loss = 2.4824
#     Epoch 3/3 — loss = 2.3866
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.3866
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 5719.44
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 5478.00
# ✓ Historique partiel sauvegardé (itération 69)
#  Temps écoulé : 35.7 min
#
# =========== Iteration 70/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.1805
#     Epoch 2/3 — loss = 2.0547
#     Epoch 3/3 — loss = 1.9564
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.9564
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -1487.40
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -2082.34
# ✓ Historique partiel sauvegardé (itération 70)
# ✓ Dataset sauvegardé (itération 70)
#  Temps écoulé : 36.2 min
#
# =========== Iteration 71/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.9290
#     Epoch 2/3 — loss = 1.8072
#     Epoch 3/3 — loss = 1.7099
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.7099
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 5132.50
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 6112.34
# ✓ Historique partiel sauvegardé (itération 71)
#  Temps écoulé : 36.8 min
#
# =========== Iteration 72/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.5611
#     Epoch 2/3 — loss = 2.4704
#     Epoch 3/3 — loss = 2.3990
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.3990
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 7225.56
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 7029.88
# ✓ Historique partiel sauvegardé (itération 72)
#  Temps écoulé : 37.3 min
#
# =========== Iteration 73/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 3.0401
#     Epoch 2/3 — loss = 2.9114
#     Epoch 3/3 — loss = 2.8093
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.8093
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 8420.52
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 8521.28
# ✓ Historique partiel sauvegardé (itération 73)
#  Temps écoulé : 37.8 min
#
# =========== Iteration 74/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.7663
#     Epoch 2/3 — loss = 2.6638
#     Epoch 3/3 — loss = 2.5734
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.5734
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 12697.22
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 12503.04
# ✓ Historique partiel sauvegardé (itération 74)
#  Temps écoulé : 38.3 min
#
# =========== Iteration 75/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.0711
#     Epoch 2/3 — loss = 1.9983
#     Epoch 3/3 — loss = 1.9406
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.9406
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 10415.80
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 10912.16
# ✓ Historique partiel sauvegardé (itération 75)
# ✓ Dataset sauvegardé (itération 75)
#  Temps écoulé : 38.7 min
#
# =========== Iteration 76/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 1.8995
#     Epoch 2/3 — loss = 1.8383
#     Epoch 3/3 — loss = 1.7790
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.7790
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 12928.82
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 10873.24
# ✓ Historique partiel sauvegardé (itération 76)
#  Temps écoulé : 39.2 min
#
# =========== Iteration 77/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.2859
#     Epoch 2/3 — loss = 2.2077
#     Epoch 3/3 — loss = 2.1443
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.1443
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : -4777.72
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : -3376.64
# ✓ Historique partiel sauvegardé (itération 77)
#  Temps écoulé : 39.7 min
#
# =========== Iteration 78/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.4417
#     Epoch 2/3 — loss = 2.3371
#     Epoch 3/3 — loss = 2.2514
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.2514
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 10732.46
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 10974.72
# ✓ Historique partiel sauvegardé (itération 78)
#  Temps écoulé : 40.3 min
#
# =========== Iteration 79/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.5354
#     Epoch 2/3 — loss = 2.3795
#     Epoch 3/3 — loss = 2.2524
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 2.2524
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 12857.12
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 13094.74
# ✓ Historique partiel sauvegardé (itération 79)
#  Temps écoulé : 40.8 min
#
# =========== Iteration 80/80 DAgger ===========
#
# [Phase 1] Entraînement supervisé (imitation expert)
#   → Sous-échantillonnage du buffer DAgger : 30000 → 12000 exemples
#   → Entraînement supervisé sur 12000 exemples (24 batches)
#     Epoch 1/3 — loss = 2.0357
#     Epoch 2/3 — loss = 1.8983
#     Epoch 3/3 — loss = 1.7958
#   ✓ Entraînement supervisé terminé.
#
#   → Loss moyenne = 1.7958
#
# [Phase 2] Collecte DAgger (1 semaine simulée)
#   → Reward élève sur 10080 steps : 11350.84
#   → Steps joués : 10080
#   → Taille du buffer DAgger : (30000, 23)
#
# [Phase 3] Évaluation (1 semaine complète, 10080 steps)
#   → Reward élève en évaluation (10080 steps) : 11738.98
# ✓ Historique partiel sauvegardé (itération 80)
# ✓ Dataset sauvegardé (itération 80)
#  Temps écoulé : 41.3 min
#
# === FIN DU DAgger — VERSION ÉPISODES 10080 STEPS ===
#
#
# ✓ Modèle final sauvegardé : student_dagger_expertv4_final.zip
